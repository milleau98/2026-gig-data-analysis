# %% [markdown]
# <a href="https://colab.research.google.com/github/milleau98/2026-gig-data-analysis/blob/main/notebooks/google_trends_pull.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytrends pandas

# %%
from pytrends.request import TrendReq
import pandas as pd
import time

# connect to Google trends
pytrends = TrendReq(hl='en-US', tz=360)

anchor = 'Uber'

keyword_groups = [
    [anchor,'Lyft','DoorDash','Instacart','Grubhub'],
    [anchor, 'Fiverr','Upwork','side hustle','gig'],
    [anchor, 'Herbalife','Primerica','Tupperware','Avon']
]

all_data = []

for i, group in enumerate(keyword_groups):
  # timeframe and geo
  pytrends.build_payload(group, timeframe='2010-01-01 2025-12-31', geo='US')

  df=pytrends.interest_over_time()

  df=df.drop(columns=['isPartial'])

  # store anchor values
  if i == 0:
    anchor_series = df[anchor]
  else:
    scale_factor = anchor_series/df[anchor]
    df = df.multiply(scale_factor, axis=0)


  all_data.append(df.drop(columns=[anchor]))

  time.sleep(15)

# combine groups of data
final_data = pd.concat(all_data, axis=1)

final_data.head()
# Out:
# ---------------------------------------------------------------------------
# TooManyRequestsError                      Traceback (most recent call last)
# /tmp/ipykernel_325/2532207124.py in <cell line: 0>()
#      20   pytrends.build_payload(group, timeframe='2010-01-01 2025-12-31', geo='US')
#      21
# ---> 22   df=pytrends.interest_over_time()
#      23
#      24   df=df.drop(columns=['isPartial'])
#
# /usr/local/lib/python3.12/dist-packages/pytrends/request.py in interest_over_time(self)
#     230
#     231         # make the request and parse the returned json
# --> 232         req_json = self._get_data(
#     233             url=TrendReq.INTEREST_OVER_TIME_URL,
#     234             method=TrendReq.GET_METHOD,
#
# /usr/local/lib/python3.12/dist-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     157         else:
#     158             if response.status_code == status_codes.codes.too_many_requests:
# ...

# %%
quarterly = final_data.resample("QE").mean()
quarterly.head()
# Out:
#                 Uber  Lyft  DoorDash  ...  Tupperware       Avon  passive income
# date                                  ...
# 2010-03-31  2.000000   0.0       0.0  ...   11.333333  83.000000             1.0
# 2010-06-30  2.000000   0.0       0.0  ...   11.000000  92.666667             1.0
# 2010-09-30  2.333333   0.0       0.0  ...   11.000000  95.333333             1.0
# 2010-12-31  2.000000   0.0       0.0  ...   11.000000  87.666667             1.0
# 2011-03-31  2.333333   0.0       0.0  ...   10.333333  81.666667             1.0
#
# [5 rows x 14 columns]

# %%
# create dataset files
final_data.to_csv('data/google_trends_monthly.csv')
quarterly.to_csv('data/google_trends_quarterly.csv')

# %%
# download as csv
from google.colab import files
files.download('google_trends_monthly.csv')
files.download('google_trends_quarterly.csv')
